# %% [markdown]
# # Parkinson's Disease Detection using Parkinson's Spiral Drawing and CNN
#
# ![](https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/Parkinsons-Disease.png)

# %% [markdown]
# ### Cloning GitHub Repository for dataset

# %%
! git clone https://github.com/SaishShinde/Parkinsons-Spiral--Part.git
# Out:
# Cloning into 'Parkinsons-Spiral--Part'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 24 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (24/24), done.

# %% [markdown]
# ### Importing the required Libraries and packages

# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd

# %% [markdown]
# ### Loading Dataset

# %%
data_train = np.load('/content/Parkinsons-Spiral--Part/dataset/train_set.npz', allow_pickle=True)
x_train = data_train['arr_0']
y_train = data_train['arr_1']

print(x_train.shape)
print(y_train.shape)
# Out:
# (72, 256, 256, 3)
# (72,)

# %%
data_test = np.load('/content/Parkinsons-Spiral--Part/dataset/test_set.npz', allow_pickle=True)
x_test = data_test['arr_0']
y_test = data_test['arr_1']

print(x_test.shape)
print(y_test.shape)
# Out:
# (30, 256, 256, 3)
# (30,)

# %% [markdown]
# ### Data Distribution

# %%
unique_train, count = np.unique(y_train, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_train, count).set_title("Number of training images per category:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_test, count_test).set_title("Number of testing images per category:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# As can be seen, though the dataset is balanced but contains very less data points

# %% [markdown]
# ### Augmenting the Dataset

# %%
train_data_generator = ImageDataGenerator(rotation_range=360, 
                                    width_shift_range=0.0, 
                                    height_shift_range=0.0, 
                                    horizontal_flip=True, 
                                    vertical_flip=True)

x = list(x_train)
y = list(y_train)

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)
print(len(x_aug_train))
print(len(y_aug_train))

x_train = x + x_aug_train
y_train = y + y_aug_train
print(len(x_train))
print(len(y_train))

test_data_generator = ImageDataGenerator(rotation_range=360, 
                                    width_shift_range=0.0, 
                                    height_shift_range=0.0, 
                                    horizontal_flip=True, 
                                    vertical_flip=True)

x = list(x_test)
y = list(y_test)

x_aug_test = []
y_aug_test = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = test_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(20):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_test.append(aug_image)
        y_aug_test.append(v)
print(len(x_aug_test))
print(len(y_aug_test))

x_test = x + x_aug_test
y_test = y + y_aug_test
print(len(x_test))
print(len(y_test))
# Out:
# 5040
# 5040
# 5112
# 5112
# 600
# 600
# 630
# 630

# %% [markdown]
# ### Visualizing the Images in Train and Test Set
#
# ##### Images in Train Set

# %%
# print(y_test)
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_train) if v=='healthy']
img_healthy = x_train[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_train) if v=='parkinson']
img_parkinson = x_train[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %% [markdown]
# #### Images in Test Set

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_test) if v=='healthy']
img_healthy = x_test[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_test) if v=='parkinson']
img_parkinson = x_test[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Preprocessing the Images

# %%
for i in range(len(x_train)):
    img = x_train[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_train[i] = img
    
for i in range(len(x_test)):
    img = x_test[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_test[i] = img

x_train = np.array(x_train)
x_test = np.array(x_test)

x_train = x_train/255.0
x_test = x_test/255.0

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
print(y_train.shape)

label_encoder = LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
print(y_test.shape)
# Out:
# (5112,)
# (630,)

# %% [markdown]
# ### Data Distribution after Augmentation

# %%
unique_train, count = np.unique(y_train, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_train, count).set_title("Number of training images per category after augmentation:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_test, count_test).set_title("Number of test set images per category after augmentation:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (5112, 128, 128, 1)
# (5112, 2)
# (630, 128, 128, 1)
# (630, 2)

# %% [markdown]
# ### Defining the Model

# %%
def parkinson_disease_detection_model(input_shape=(128, 128, 1)):
    regularizer = tf.keras.regularizers.l2(0.001)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))

    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))
    
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))    
    
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform', name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer='glorot_uniform', name='fc3'))
    
    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= parkinson_disease_detection_model(input_shape=(128, 128, 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 128, 128, 128)     3328
#
#  max_pooling2d (MaxPooling2D  (None, 40, 40, 128)      0
#  )
#
#  conv2 (Conv2D)              (None, 40, 40, 64)        204864
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv3 (Conv2D)              (None, 12, 12, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 4, 4, 32)          9248
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  fc1 (Dense)                 (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  fc3 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 238,146
# Trainable params: 238,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model

# %%
hist = model.fit(x_train, y_train, batch_size=128, epochs=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/70
# 40/40 [==============================] - 23s 196ms/step - loss: 0.8557 - accuracy: 0.5072 - val_loss: 0.8488 - val_accuracy: 0.5000
# Epoch 2/70
# 40/40 [==============================] - 5s 136ms/step - loss: 0.8454 - accuracy: 0.5016 - val_loss: 0.8419 - val_accuracy: 0.5000
# Epoch 3/70
# 40/40 [==============================] - 5s 136ms/step - loss: 0.8395 - accuracy: 0.4992 - val_loss: 0.8355 - val_accuracy: 0.5016
# Epoch 4/70
# 40/40 [==============================] - 5s 136ms/step - loss: 0.8329 - accuracy: 0.4973 - val_loss: 0.8294 - val_accuracy: 0.5746
# Epoch 5/70
# 40/40 [==============================] - 5s 136ms/step - loss: 0.8269 - accuracy: 0.5086 - val_loss: 0.8236 - val_accuracy: 0.6159
# Epoch 6/70
# 40/40 [==============================] - 6s 140ms/step - loss: 0.8212 - accuracy: 0.5153 - val_loss: 0.8181 - val_accuracy: 0.5000
# Epoch 7/70
# 40/40 [==============================] - 6s 141ms/step - loss: 0.8156 - accuracy: 0.5176 - val_loss: 0.8121 - val_accuracy: 0.6476
# Epoch 8/70
# 40/40 [==============================] - 6s 138ms/step - loss: 0.8105 - accuracy: 0.5276 - val_loss: 0.8061 - val_accuracy: 0.7317
# Epoch 9/70
# 40/40 [==============================] - 6s 138ms/step - loss: 0.8057 - accuracy: 0.5309 - val_loss: 0.8020 - val_accuracy: 0.6079
# Epoch 10/70
# 40/40 [==============================] - 6s 139ms/step - loss: 0.8006 - accuracy: 0.5432 - val_loss: 0.7958 - val_accuracy: 0.7683
# Epoch 11/70
# 40/40 [==============================] - 6s 139ms/step - loss: 0.7949 - accuracy: 0.5499 - val_loss: 0.7891 - val_accuracy: 0.7095
# Epoch 12/70
# 40/40 [==============================] - 6s 139ms/step - loss: 0.7900 - accuracy: 0.5536 - val_loss: 0.7828 - val_accuracy: 0.7587
# Epoch 13/70
# 40/40 [==============================] - 6s 139ms/step - loss: 0.7850 - accuracy: 0.5618 - val_loss: 0.7772 - val_accuracy: 0.6889
# Epoch 14/70
# 40/40 [==============================] - 6s 140ms/step - loss: 0.7805 - accuracy: 0.5663 - val_loss: 0.7734 - val_accuracy: 0.5000
# Epoch 15/70
# 40/40 [==============================] - 6s 141ms/step - loss: 0.7747 - accuracy: 0.5822 - val_loss: 0.7645 - val_accuracy: 0.7095
# Epoch 16/70
# 40/40 [==============================] - 6s 143ms/step - loss: 0.7711 - accuracy: 0.5781 - val_loss: 0.7655 - val_accuracy: 0.6222
# Epoch 17/70
# 40/40 [==============================] - 6s 141ms/step - loss: 0.7645 - accuracy: 0.5951 - val_loss: 0.7547 - val_accuracy: 0.6714
# Epoch 18/70
# 40/40 [==============================] - 6s 141ms/step - loss: 0.7581 - accuracy: 0.6031 - val_loss: 0.7468 - val_accuracy: 0.6190
# Epoch 19/70
# 40/40 [==============================] - 6s 141ms/step - loss: 0.7487 - accuracy: 0.6315 - val_loss: 0.7367 - val_accuracy: 0.7397
# Epoch 20/70
# 40/40 [==============================] - 6s 142ms/step - loss: 0.7363 - accuracy: 0.6551 - val_loss: 0.7301 - val_accuracy: 0.7127
# Epoch 21/70
# 40/40 [==============================] - 6s 143ms/step - loss: 0.7284 - accuracy: 0.6655 - val_loss: 0.7188 - val_accuracy: 0.7413
# Epoch 22/70
# 40/40 [==============================] - 6s 143ms/step - loss: 0.7166 - accuracy: 0.6868 - val_loss: 0.7055 - val_accuracy: 0.8000
# Epoch 23/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.7026 - accuracy: 0.7034 - val_loss: 0.6959 - val_accuracy: 0.7921
# Epoch 24/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.6866 - accuracy: 0.7007 - val_loss: 0.6837 - val_accuracy: 0.7603
# Epoch 25/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.6732 - accuracy: 0.7195 - val_loss: 0.6780 - val_accuracy: 0.7143
# Epoch 26/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.6593 - accuracy: 0.7257 - val_loss: 0.6803 - val_accuracy: 0.6683
# Epoch 27/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.6422 - accuracy: 0.7432 - val_loss: 0.6730 - val_accuracy: 0.6619
# Epoch 28/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.6368 - accuracy: 0.7418 - val_loss: 0.6469 - val_accuracy: 0.7635
# Epoch 29/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.6260 - accuracy: 0.7418 - val_loss: 0.6398 - val_accuracy: 0.7857
# Epoch 30/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.6117 - accuracy: 0.7606 - val_loss: 0.6404 - val_accuracy: 0.7190
# Epoch 31/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.6084 - accuracy: 0.7586 - val_loss: 0.6284 - val_accuracy: 0.7476
# Epoch 32/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5997 - accuracy: 0.7612 - val_loss: 0.6373 - val_accuracy: 0.6921
# Epoch 33/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.5873 - accuracy: 0.7709 - val_loss: 0.6127 - val_accuracy: 0.7333
# Epoch 34/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5856 - accuracy: 0.7715 - val_loss: 0.6108 - val_accuracy: 0.7222
# Epoch 35/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.5803 - accuracy: 0.7703 - val_loss: 0.7243 - val_accuracy: 0.6333
# Epoch 36/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5782 - accuracy: 0.7741 - val_loss: 0.5889 - val_accuracy: 0.7587
# Epoch 37/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5610 - accuracy: 0.7889 - val_loss: 0.5809 - val_accuracy: 0.7746
# Epoch 38/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5546 - accuracy: 0.7874 - val_loss: 0.5913 - val_accuracy: 0.7270
# Epoch 39/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5506 - accuracy: 0.7913 - val_loss: 0.5841 - val_accuracy: 0.7302
# Epoch 40/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.5398 - accuracy: 0.7995 - val_loss: 0.5673 - val_accuracy: 0.7635
# Epoch 41/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5413 - accuracy: 0.7946 - val_loss: 0.5916 - val_accuracy: 0.7159
# Epoch 42/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5256 - accuracy: 0.8005 - val_loss: 0.5742 - val_accuracy: 0.7333
# Epoch 43/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5269 - accuracy: 0.8013 - val_loss: 0.5411 - val_accuracy: 0.7746
# Epoch 44/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5195 - accuracy: 0.8079 - val_loss: 0.5370 - val_accuracy: 0.7762
# Epoch 45/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.5089 - accuracy: 0.8136 - val_loss: 0.5684 - val_accuracy: 0.7524
# Epoch 46/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.5018 - accuracy: 0.8167 - val_loss: 0.5260 - val_accuracy: 0.7683
# Epoch 47/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4857 - accuracy: 0.8304 - val_loss: 0.5186 - val_accuracy: 0.7825
# Epoch 48/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4761 - accuracy: 0.8294 - val_loss: 0.5208 - val_accuracy: 0.7794
# Epoch 49/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4849 - accuracy: 0.8263 - val_loss: 0.5092 - val_accuracy: 0.7825
# Epoch 50/70
# 40/40 [==============================] - 6s 148ms/step - loss: 0.4771 - accuracy: 0.8298 - val_loss: 0.5151 - val_accuracy: 0.7746
# Epoch 51/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4651 - accuracy: 0.8388 - val_loss: 0.4998 - val_accuracy: 0.7952
# Epoch 52/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4632 - accuracy: 0.8402 - val_loss: 0.5106 - val_accuracy: 0.7794
# Epoch 53/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4674 - accuracy: 0.8386 - val_loss: 0.4928 - val_accuracy: 0.7952
# Epoch 54/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4700 - accuracy: 0.8349 - val_loss: 0.4983 - val_accuracy: 0.7778
# Epoch 55/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4556 - accuracy: 0.8415 - val_loss: 0.4943 - val_accuracy: 0.7825
# Epoch 56/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4393 - accuracy: 0.8554 - val_loss: 0.4887 - val_accuracy: 0.7841
# Epoch 57/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4359 - accuracy: 0.8564 - val_loss: 0.5126 - val_accuracy: 0.8032
# Epoch 58/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4355 - accuracy: 0.8582 - val_loss: 0.4911 - val_accuracy: 0.8000
# Epoch 59/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4216 - accuracy: 0.8635 - val_loss: 0.4660 - val_accuracy: 0.8143
# Epoch 60/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4199 - accuracy: 0.8619 - val_loss: 0.4566 - val_accuracy: 0.8238
# Epoch 61/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4232 - accuracy: 0.8578 - val_loss: 0.4539 - val_accuracy: 0.8286
# Epoch 62/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4081 - accuracy: 0.8725 - val_loss: 0.4669 - val_accuracy: 0.8286
# Epoch 63/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4100 - accuracy: 0.8744 - val_loss: 0.4578 - val_accuracy: 0.8238
# Epoch 64/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.3947 - accuracy: 0.8773 - val_loss: 0.4509 - val_accuracy: 0.8238
# Epoch 65/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.3974 - accuracy: 0.8772 - val_loss: 0.4882 - val_accuracy: 0.8127
# Epoch 66/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.3997 - accuracy: 0.8764 - val_loss: 0.4310 - val_accuracy: 0.8460
# Epoch 67/70
# 40/40 [==============================] - 6s 148ms/step - loss: 0.3876 - accuracy: 0.8848 - val_loss: 0.4485 - val_accuracy: 0.8333
# Epoch 68/70
# 40/40 [==============================] - 6s 148ms/step - loss: 0.3744 - accuracy: 0.8891 - val_loss: 0.4340 - val_accuracy: 0.8508
# Epoch 69/70
# 40/40 [==============================] - 6s 148ms/step - loss: 0.3810 - accuracy: 0.8844 - val_loss: 0.4466 - val_accuracy: 0.8397
# Epoch 70/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.3638 - accuracy: 0.8901 - val_loss: 0.4505 - val_accuracy: 0.8333

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### Classification Report

# %%
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82       315
#            1       0.79      0.92      0.85       315
#
#     accuracy                           0.83       630
#    macro avg       0.84      0.83      0.83       630
# weighted avg       0.84      0.83      0.83       630

# %% [markdown]
# ### Confusion Matrix

# %%
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')

# %% [markdown]
# ### Saving the Model

# %%
model.save('parkinson_disease_detection.h5')

# %% [markdown]
# ### Testing Model on Images

# %%
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread('/content/Parkinsons-Spiral--Part/dataset/test_image_healthy.png')
image_parkinson = cv2.imread('/content/Parkinsons-Spiral--Part/dataset/test_image_parkinson.png')

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

# %%
ypred_healthy = model.predict(image_healthy)
ypred_parkinson = model.predict(image_parkinson)

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
img_healthy = np.squeeze(img_healthy, axis=-1)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
image_parkinson = np.squeeze(image_parkinson, axis=-1)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()
