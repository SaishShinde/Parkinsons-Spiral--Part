# %% [markdown]
# <a href="https://colab.research.google.com/github/SaishShinde/Parkinsons-Spiral--Part/blob/main/Parkinson's_Disease_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parkinson's Disease Detection using Parkinson's Spiral Drawing and CNN
#
# ![](https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/Parkinsons-Disease.png)

# %% [markdown]
# ### Cloning GitHub Repository for dataset

# %%
! git clone https://github.com/Yuvnish017/Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing.git
# Out:
# Cloning into 'Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing'...
# remote: Enumerating objects: 26, done.
# remote: Total 26 (delta 0), reused 0 (delta 0), pack-reused 26
# Unpacking objects: 100% (26/26), done.

# %% [markdown]
# ### Importing the required Libraries and packages

# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd

# %% [markdown]
# ### Loading Dataset

# %%
data_train = np.load('/content/Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing/dataset/train_set.npz', allow_pickle=True)
x_train = data_train['arr_0']
y_train = data_train['arr_1']

print(x_train.shape)
print(y_train.shape)
# Out:
# (72, 256, 256, 3)
# (72,)

# %%
data_test = np.load('/content/Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing/dataset/test_set.npz', allow_pickle=True)
x_test = data_test['arr_0']
y_test = data_test['arr_1']

print(x_test.shape)
print(y_test.shape)
# Out:
# (30, 256, 256, 3)
# (30,)

# %% [markdown]
# ### Data Distribution

# %%
unique_train, count = np.unique(y_train, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_train, count).set_title("Number of training images per category:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_test, count_test).set_title("Number of testing images per category:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# As can be seen, though the dataset is balanced but contains very less data points

# %% [markdown]
# ### Augmenting the Dataset

# %%
train_data_generator = ImageDataGenerator(rotation_range=360, 
                                    width_shift_range=0.0, 
                                    height_shift_range=0.0, 
                                    horizontal_flip=True, 
                                    vertical_flip=True)

x = list(x_train)
y = list(y_train)

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)
print(len(x_aug_train))
print(len(y_aug_train))

x_train = x + x_aug_train
y_train = y + y_aug_train
print(len(x_train))
print(len(y_train))

test_data_generator = ImageDataGenerator(rotation_range=360, 
                                    width_shift_range=0.0, 
                                    height_shift_range=0.0, 
                                    horizontal_flip=True, 
                                    vertical_flip=True)

x = list(x_test)
y = list(y_test)

x_aug_test = []
y_aug_test = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = test_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(20):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_test.append(aug_image)
        y_aug_test.append(v)
print(len(x_aug_test))
print(len(y_aug_test))

x_test = x + x_aug_test
y_test = y + y_aug_test
print(len(x_test))
print(len(y_test))
# Out:
# 5040
# 5040
# 5112
# 5112
# 600
# 600
# 630
# 630

# %% [markdown]
# ### Visualizing the Images in Train and Test Set
#
# ##### Images in Train Set

# %%
# print(y_test)
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_train) if v=='healthy']
img_healthy = x_train[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_train) if v=='parkinson']
img_parkinson = x_train[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %% [markdown]
# #### Images in Test Set

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_test) if v=='healthy']
img_healthy = x_test[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_test) if v=='parkinson']
img_parkinson = x_test[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Preprocessing the Images

# %%
for i in range(len(x_train)):
    img = x_train[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_train[i] = img
    
for i in range(len(x_test)):
    img = x_test[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_test[i] = img

x_train = np.array(x_train)
x_test = np.array(x_test)

x_train = x_train/255.0
x_test = x_test/255.0

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
print(y_train.shape)

label_encoder = LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
print(y_test.shape)
# Out:
# (5112,)
# (630,)

# %% [markdown]
# ### Data Distribution after Augmentation

# %%
unique_train, count = np.unique(y_train, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_train, count).set_title("Number of training images per category after augmentation:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_test, count_test).set_title("Number of test set images per category after augmentation:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (5112, 128, 128, 1)
# (5112, 2)
# (630, 128, 128, 1)
# (630, 2)

# %% [markdown]
# ### Defining the Model

# %%
def parkinson_disease_detection_model(input_shape=(128, 128, 1)):
    regularizer = tf.keras.regularizers.l2(0.001)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))

    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))
    
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))    
    
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform', name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer='glorot_uniform', name='fc3'))
    
    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= parkinson_disease_detection_model(input_shape=(128, 128, 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 128, 128, 128)     3328
#
#  max_pooling2d (MaxPooling2D  (None, 40, 40, 128)      0
#  )
#
#  conv2 (Conv2D)              (None, 40, 40, 64)        204864
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv3 (Conv2D)              (None, 12, 12, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 4, 4, 32)          9248
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  fc1 (Dense)                 (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  fc3 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 238,146
# Trainable params: 238,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model

# %%
hist = model.fit(x_train, y_train, batch_size=128, epochs=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/70
# 40/40 [==============================] - 24s 197ms/step - loss: 0.8525 - accuracy: 0.5023 - val_loss: 0.8475 - val_accuracy: 0.5000
# Epoch 2/70
# 40/40 [==============================] - 5s 136ms/step - loss: 0.8444 - accuracy: 0.5016 - val_loss: 0.8401 - val_accuracy: 0.5302
# Epoch 3/70
# 40/40 [==============================] - 6s 139ms/step - loss: 0.8374 - accuracy: 0.4965 - val_loss: 0.8334 - val_accuracy: 0.5000
# Epoch 4/70
# 40/40 [==============================] - 6s 143ms/step - loss: 0.8306 - accuracy: 0.5094 - val_loss: 0.8271 - val_accuracy: 0.5000
# Epoch 5/70
# 40/40 [==============================] - 5s 137ms/step - loss: 0.8249 - accuracy: 0.5016 - val_loss: 0.8211 - val_accuracy: 0.5000
# Epoch 6/70
# 40/40 [==============================] - 5s 137ms/step - loss: 0.8189 - accuracy: 0.4963 - val_loss: 0.8152 - val_accuracy: 0.5000
# Epoch 7/70
# 40/40 [==============================] - 6s 138ms/step - loss: 0.8132 - accuracy: 0.5102 - val_loss: 0.8100 - val_accuracy: 0.5000
# Epoch 8/70
# 40/40 [==============================] - 6s 138ms/step - loss: 0.8082 - accuracy: 0.5068 - val_loss: 0.8055 - val_accuracy: 0.5238
# Epoch 9/70
# 40/40 [==============================] - 6s 139ms/step - loss: 0.8031 - accuracy: 0.5129 - val_loss: 0.8005 - val_accuracy: 0.7365
# Epoch 10/70
# 40/40 [==============================] - 6s 139ms/step - loss: 0.7988 - accuracy: 0.5108 - val_loss: 0.7956 - val_accuracy: 0.5000
# Epoch 11/70
# 40/40 [==============================] - 6s 141ms/step - loss: 0.7943 - accuracy: 0.5168 - val_loss: 0.7914 - val_accuracy: 0.7349
# Epoch 12/70
# 40/40 [==============================] - 6s 148ms/step - loss: 0.7902 - accuracy: 0.5151 - val_loss: 0.7871 - val_accuracy: 0.6016
# Epoch 13/70
# 40/40 [==============================] - 6s 148ms/step - loss: 0.7858 - accuracy: 0.5381 - val_loss: 0.7835 - val_accuracy: 0.5667
# Epoch 14/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.7835 - accuracy: 0.5172 - val_loss: 0.7794 - val_accuracy: 0.7159
# Epoch 15/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.7787 - accuracy: 0.5379 - val_loss: 0.7755 - val_accuracy: 0.5000
# Epoch 16/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.7757 - accuracy: 0.5333 - val_loss: 0.7701 - val_accuracy: 0.5000
# Epoch 17/70
# 40/40 [==============================] - 6s 143ms/step - loss: 0.7730 - accuracy: 0.5211 - val_loss: 0.7664 - val_accuracy: 0.7540
# Epoch 18/70
# 40/40 [==============================] - 6s 143ms/step - loss: 0.7698 - accuracy: 0.5264 - val_loss: 0.7632 - val_accuracy: 0.7444
# Epoch 19/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.7640 - accuracy: 0.5597 - val_loss: 0.7579 - val_accuracy: 0.7111
# Epoch 20/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.7601 - accuracy: 0.5657 - val_loss: 0.7527 - val_accuracy: 0.7254
# Epoch 21/70
# 40/40 [==============================] - 6s 148ms/step - loss: 0.7572 - accuracy: 0.5593 - val_loss: 0.7455 - val_accuracy: 0.6016
# Epoch 22/70
# 40/40 [==============================] - 6s 143ms/step - loss: 0.7526 - accuracy: 0.5777 - val_loss: 0.7396 - val_accuracy: 0.7492
# Epoch 23/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.7446 - accuracy: 0.5996 - val_loss: 0.7321 - val_accuracy: 0.7635
# Epoch 24/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.7390 - accuracy: 0.6031 - val_loss: 0.7210 - val_accuracy: 0.7460
# Epoch 25/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.7304 - accuracy: 0.6277 - val_loss: 0.7148 - val_accuracy: 0.7556
# Epoch 26/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.7216 - accuracy: 0.6473 - val_loss: 0.7019 - val_accuracy: 0.8048
# Epoch 27/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.7123 - accuracy: 0.6540 - val_loss: 0.6922 - val_accuracy: 0.7794
# Epoch 28/70
# 40/40 [==============================] - 6s 144ms/step - loss: 0.6995 - accuracy: 0.6757 - val_loss: 0.6833 - val_accuracy: 0.7429
# Epoch 29/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.6800 - accuracy: 0.6937 - val_loss: 0.6910 - val_accuracy: 0.6571
# Epoch 30/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.6722 - accuracy: 0.6937 - val_loss: 0.6654 - val_accuracy: 0.7413
# Epoch 31/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.6490 - accuracy: 0.7271 - val_loss: 0.6723 - val_accuracy: 0.6508
# Epoch 32/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.6412 - accuracy: 0.7345 - val_loss: 0.6471 - val_accuracy: 0.7079
# Epoch 33/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.6298 - accuracy: 0.7388 - val_loss: 0.6517 - val_accuracy: 0.6683
# Epoch 34/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.6203 - accuracy: 0.7453 - val_loss: 0.6278 - val_accuracy: 0.7714
# Epoch 35/70
# 40/40 [==============================] - 6s 145ms/step - loss: 0.6060 - accuracy: 0.7545 - val_loss: 0.6240 - val_accuracy: 0.7571
# Epoch 36/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5966 - accuracy: 0.7608 - val_loss: 0.6342 - val_accuracy: 0.6778
# Epoch 37/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5850 - accuracy: 0.7653 - val_loss: 0.6357 - val_accuracy: 0.6571
# Epoch 38/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5798 - accuracy: 0.7735 - val_loss: 0.6074 - val_accuracy: 0.7127
# Epoch 39/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5846 - accuracy: 0.7623 - val_loss: 0.5987 - val_accuracy: 0.7730
# Epoch 40/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5614 - accuracy: 0.7844 - val_loss: 0.6251 - val_accuracy: 0.6556
# Epoch 41/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5671 - accuracy: 0.7717 - val_loss: 0.6178 - val_accuracy: 0.6698
# Epoch 42/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5510 - accuracy: 0.7903 - val_loss: 0.6170 - val_accuracy: 0.6714
# Epoch 43/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5391 - accuracy: 0.8003 - val_loss: 0.5746 - val_accuracy: 0.7365
# Epoch 44/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5304 - accuracy: 0.7991 - val_loss: 0.5654 - val_accuracy: 0.7524
# Epoch 45/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5249 - accuracy: 0.7968 - val_loss: 0.5553 - val_accuracy: 0.7667
# Epoch 46/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5202 - accuracy: 0.8034 - val_loss: 0.5545 - val_accuracy: 0.8095
# Epoch 47/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5193 - accuracy: 0.8005 - val_loss: 0.5397 - val_accuracy: 0.8032
# Epoch 48/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5043 - accuracy: 0.8073 - val_loss: 0.5506 - val_accuracy: 0.7651
# Epoch 49/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4944 - accuracy: 0.8126 - val_loss: 0.5277 - val_accuracy: 0.7984
# Epoch 50/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4926 - accuracy: 0.8189 - val_loss: 0.5439 - val_accuracy: 0.7683
# Epoch 51/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4815 - accuracy: 0.8157 - val_loss: 0.5297 - val_accuracy: 0.8222
# Epoch 52/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4834 - accuracy: 0.8202 - val_loss: 0.5517 - val_accuracy: 0.7365
# Epoch 53/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4742 - accuracy: 0.8220 - val_loss: 0.5326 - val_accuracy: 0.7698
# Epoch 54/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4645 - accuracy: 0.8345 - val_loss: 0.5090 - val_accuracy: 0.8127
# Epoch 55/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4581 - accuracy: 0.8322 - val_loss: 0.5027 - val_accuracy: 0.8048
# Epoch 56/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4524 - accuracy: 0.8339 - val_loss: 0.5024 - val_accuracy: 0.8143
# Epoch 57/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4384 - accuracy: 0.8488 - val_loss: 0.4980 - val_accuracy: 0.8048
# Epoch 58/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4372 - accuracy: 0.8423 - val_loss: 0.4932 - val_accuracy: 0.8079
# Epoch 59/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4346 - accuracy: 0.8470 - val_loss: 0.4906 - val_accuracy: 0.8032
# Epoch 60/70
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4183 - accuracy: 0.8582 - val_loss: 0.4860 - val_accuracy: 0.8206
# Epoch 61/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4100 - accuracy: 0.8595 - val_loss: 0.4852 - val_accuracy: 0.7905
# Epoch 62/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4118 - accuracy: 0.8584 - val_loss: 0.4804 - val_accuracy: 0.8206
# Epoch 63/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.3975 - accuracy: 0.8656 - val_loss: 0.4781 - val_accuracy: 0.8397
# Epoch 64/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.3950 - accuracy: 0.8680 - val_loss: 0.4730 - val_accuracy: 0.8222
# Epoch 65/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.3915 - accuracy: 0.8730 - val_loss: 0.5193 - val_accuracy: 0.8159
# Epoch 66/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.3941 - accuracy: 0.8709 - val_loss: 0.4662 - val_accuracy: 0.8429
# Epoch 67/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.3792 - accuracy: 0.8828 - val_loss: 0.4658 - val_accuracy: 0.8286
# Epoch 68/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.3719 - accuracy: 0.8789 - val_loss: 0.4762 - val_accuracy: 0.8317
# Epoch 69/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.3752 - accuracy: 0.8795 - val_loss: 0.4603 - val_accuracy: 0.8317
# Epoch 70/70
# 40/40 [==============================] - 6s 146ms/step - loss: 0.3620 - accuracy: 0.8897 - val_loss: 0.4629 - val_accuracy: 0.8286

# %% [markdown]
# ### Loss and Accuracy Plot

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### Classification Report

# %%
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       315
#            1       0.85      0.79      0.82       315
#
#     accuracy                           0.83       630
#    macro avg       0.83      0.83      0.83       630
# weighted avg       0.83      0.83      0.83       630

# %% [markdown]
# ### Confusion Matrix

# %%
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')

# %% [markdown]
# ### Saving the Model

# %%
model.save('parkinson_disease_detection.h5')

# %% [markdown]
# ### Testing Model on Images

# %%
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread('/content/Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing/dataset/3.png')
image_parkinson = cv2.imread('/content/Parkinsons_Disease_Detection_using_Parkinsons_Spiral_Drawing/dataset/test_image_healthy.png')

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

# %%
ypred_healthy = model.predict(image_healthy)
ypred_parkinson = model.predict(image_parkinson)

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
img_healthy = np.squeeze(img_healthy, axis=-1)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
image_parkinson = np.squeeze(image_parkinson, axis=-1)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()
